# %% [markdown]
# <a href="https://colab.research.google.com/github/sergekamanzi/Machine-learning-CALCULUS/blob/main/Calculus_Assignment_%5BdameDOLLA%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 1: Write a dynamic function to find the derivative of any function f(x)

# %%
#TO DO: Create a function that does a derivative for any function
import sympy as sp

def dy_dx(func, var):
    # Define the variable
    var = sp.symbols(var)
    # Compute the derivative of the function
    derivative = sp.diff(func, var)
    return derivative

# %% [markdown]
# # Task 2: Test the derivative function written with an equation of your choice
# *NB: Must have atleast 2 minimas and atleast 2 maximas*

# %%
# Define the variable
x = sp.symbols('x')

# Equation : f(x) = x^5 - 10x^3 + 15x
f = x**5 - 10*x**3 + 15*x

# Compute the derivative of the function
derivative_f = dy_dx(f, 'x')
print(f"Derivative of f(x) = x^5 - 10x^3 + 15x=> {derivative_f}")
# Out:
# Derivative of f(x) = x^5 - 10x^3 + 15x=> 5*x**4 - 30*x**2 + 15

# %% [markdown]
# #Task 3: Plot a graph of the Equation must have 4 points (2 minimas and 2 maximas)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the variable and function
x = sp.symbols('x')
f = x**5 - 10*x**3 + 15*x

# Compute the derivative
derivative_f = sp.diff(f, x)

# Finding critical points
critical_points_f = sp.solve(derivative_f, x)

# Create an array of x values for plotting
x_vals = np.linspace(-3, 3, 400)
# Evaluate the function for these x values
f_vals = [f.subs(x, val) for val in x_vals]

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(x_vals, f_vals, label=r'$f(x) = x^5 - 10x^3 + 15x$', color='blue')

# Mark critical points on the plot
for point in critical_points_f:
    y_val = f.subs(x, point)
    plt.scatter(float(point), float(y_val), color='blue', zorder=5)
    plt.text(float(point), float(y_val), f'({float(point):.2f}, {float(y_val):.2f})', fontsize=9, ha='right')

# Add grid, labels, title, and legend
plt.axhline(0, color='black', lw=0.5, ls='--')
plt.axvline(0, color='black', lw=0.5, ls='--')
plt.title('Graph of the Function with Critical Points')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid()

# Show the plot
plt.show()

# %% [markdown]
# # Task 4: Create separate array of Minimas and maximas

# %%
import sympy as sp

# Define the variable and function
x = sp.symbols('x')
f = x**5 - 10*x**3 + 15*x

# First derivative of f(x)
derivative_f = sp.diff(f, x)

# Find critical points by solving f'(x) = 0
critical_points_f = sp.solve(derivative_f, x)

# Convert critical points to decimal form for evaluation
critical_points_f_decimal = [sp.N(point) for point in critical_points_f]

# Compute the second derivative of f(x)
second_derivative_f = sp.diff(derivative_f, x)

# Arrays to hold minimas and maximas
arr_minimas = []
arr_maximas = []

# Classify critical points based on the second derivative
for point in critical_points_f_decimal:
    second_derivative_value = second_derivative_f.subs(x, point)

    # If the second derivative is positive, it's a minimum
    if second_derivative_value > 0:
        arr_minimas.append((float(point), float(f.subs(x, point))))

    # If the second derivative is negative, it's a maximum
    elif second_derivative_value < 0:
        arr_maximas.append((float(point), float(f.subs(x, point))))

# Print the arrays of minimas and maximas
print(f'the array of minimas {arr_minimas} and the array of maximas is {arr_maximas}')
# Out:
# the array of minimas [(-0.7419637843027258, -7.269730716664469), (2.3344142183389773, -22.87249473291414)] and the array of maximas is [(0.7419637843027258, 7.269730716664469), (-2.3344142183389773, 22.87249473291414)]

# %%
# Find the global maxima and minima by comparing y-values
Global_maxima = max(arr_maximas, key=lambda t: t[1]) if arr_maximas else None
Global_minima = min(arr_minimas, key=lambda t: t[1]) if arr_minimas else None

# Print the global maxima and minima
print(f'The global maxima is {Global_maxima}')
print(f'The global minima is {Global_minima}')
# Out:
# The global maxima is (-2.3344142183389773, 22.87249473291414)
# The global minima is (2.3344142183389773, -22.87249473291414)

# %% [markdown]
# **TASK 5 : find the area of the curve**

# %%
def area_under_curve(func, var, lower_limit, upper_limit):
    # Define the variable
    var = sp.symbols(var)
    # Compute the definite integral of the function between the limits
    area = sp.integrate(func, (var, lower_limit, upper_limit))
    return area

# Define the variable and function
x = sp.symbols('x')
f = x**5 - 10*x**3 + 15*x

# Define limits for area calculation
lower_limit = -1
upper_limit = 0

# Calculate the area under the curve
area = area_under_curve(f, 'x', lower_limit, upper_limit)

# Output the result
print(f"The area under the curve from x = {lower_limit} to x = {upper_limit} is {area}")
# Out:
# The area under the curve from x = -1 to x = 0 is -31/6

# %% [markdown]
# # Things trhat may help
#
# We came up with a functon
#
# $$
# f(x) = 4x^2 + x^-1
# $$
#
# So we create a fucntion in python
#
#
#
# ```
# def f(x):
#   #see our code below
# ```

# %%
#This is an Example of a quadratic function
def f(x):
   return (4 * (x** 2)) + (x ** -1)

# %% [markdown]
# We manuall calculated the derivative  and got that
# $$
# df(x)/dx = 8x^1 + x^-2
# $$
#
# Using the formula above we find points where the derivative is 0
#
# the values are:
#
# $$
# x1 = 0.5, x1 = - 0.5,x1 = 0,
# $$
#
# If you replace this in our original formula
#
# $$
# f(0.5) = 4(0.5)^2 + (0.5^-1 = -1.0
# $$
# $$
# f(0) = 4x^2 + x^-1 = No solution
# $$
# $$
# f(-0.5) = 4x^2 + x^-1 = 1
# $$
#
# Meaning our curve is flat at point $$(0.5,1) $$ and at $$ (-0.5,1)$$
#
# Proof Pending........
#
# Here is how we tried with code and got some errors

# %%
x1 = 0.5
x2 = -0.5
x3 = 0

y1 = f(x1)
y2 = f(x2)
y3 = f(x3)

print(y2)
(0.5,3)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-3-2d333f00018d> in <cell line: 7>()
#       5 y1 = f(x1)
#       6 y2 = f(x2)
# ----> 7 y3 = f(x3)
#       8
#       9 print(y2)
#
# <ipython-input-1-6a316e2d262c> in f(x)
#       1 #This is an Example of a quadratic function
#       2 def f(x):
# ----> 3    return (4 * (x** 2)) + (x ** -1)
#
# ZeroDivisionError: 0.0 cannot be raised to a negative power

# %% [markdown]
# # **You can now do the Rest.All the Best ........**
